# %% [markdown]
# <a href="https://colab.research.google.com/github/Manojgharge07/Datascience_Mentorship_SQL_Basic/blob/main/SQL_Pracice_Screenshot_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SQL-practice Screenshots:**

# %% [markdown]
# ![SQL_PRACICE_1.png](data:image/png;base64,...)

# %% [markdown]
# ![SQL_PRACTICE_2.png](data:image/png;base64,...)

# %% [markdown]
# ![SQL_PRACTICE_3.png](data:image/png;base64,...)
