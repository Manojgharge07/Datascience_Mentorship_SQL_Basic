# %% [markdown]
# <a href="https://colab.research.google.com/github/Manojgharge07/Datascience_Mentorship_SQL_Basic/blob/main/SQL_1_DDL_Handwritten.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Structured Query Langauge**

# %% [markdown]
# ![WhatsApp Image 2022-06-03 at 10.58.04 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2022-06-03 at 10.58.03 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2022-06-03 at 10.58.03 AM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2022-06-03 at 10.58.03 AM (2).jpeg](data:image/jpeg;base64,...)
